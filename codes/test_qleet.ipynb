# %%
import numpy as np
import qiskit
import qleet
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import numpy as np
#       2 import qiskit
# ----> 3 import qleet
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qleet/__init__.py:7
#       4 os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
#       6 # import qleet.examples
# ----> 7 import qleet.analyzers
#       8 import qleet.simulators
#       9 import qleet.interface
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qleet/analyzers/__init__.py:1
# ----> 1 import qleet.analyzers.loss_landscape
#       2 import qleet.analyzers.training_path
#       3 import qleet.analyzers.entanglement
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qleet/analyzers/loss_landscape.py:19
#      16 import tqdm.auto as tqdm
# ...
