# %%
import sys
sys.path.insert(0, '..')
import numpy as np
import qiskit
import qtm.evolution
import qtm.state
import qtm.qcompilation
import qtm.ansatz
import qtm.constant
import qtm.random_circuit
from qtm.evolution import environment, mutate, selection, crossover, utils
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
qc1 = qtm.random_circuit.generate_with_pool(3, 10)
qc2 = qtm.random_circuit.generate_with_pool(3, 10)

# %%
qc1.draw('mpl')

# %%
percent = 0.5
sub11, sub12 = utils.divide_circuit_by_depth(qc1, 1)
# sub21, sub22 = utils.divide_circuit_by_depth(qc2, 5)
# new_qc1 = qtm.utilities.compose_circuit([sub11, sub22])
# new_qc2 = qtm.utilities.compose_circuit([sub21, sub12])

# %%
qc1.draw('mpl')

# %%
sub12.depth()
# Out:
# 5
