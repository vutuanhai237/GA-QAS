# %%
import matplotlib.pyplot as plt

# n=5, d=3, f=0.7938522787939981
# n=5, d=4, f=0.5094050486111035
# n=4, d=3, f=0.8578980378037141
# n=4, d=4, f=0.8232849000754479
# n=3, d=3, f=0.8911286828992997
# n=3, d=4, f=0.8525561406821124

f2 = [0.5773293822752275,
      0.9402817802836569,
      0.9855074617131073,
      0.975024140853926,
      0.9998049550926659,
      0.9992268956399494,
      0.9996353986304316,
      0.9999936234964844,]

f3 = [0.8911286828992997, 0.8525561406821124,
      0.9401234389504806, 0.9567633634775301,
      0.963731607779609, 0.9878707619498597,
      0.9972726119280582, 0.9985858406138128,
      0.9989260643216443, 0.9985424196132385,
      0.9999373169820546, 0.9998850020786249]

f4 = [
    0.8578980378037141,
    0.8232849000754479,
    0.8973710460415105,
    0.8656902394247192,
    0.8900065746240899,
    0.910734286558027,
    0.9189413232776339,
    0.9192910879294155,
    0.9551571698889052,
    0.9540313194093217,
    0.957826776245612,
    0.995998369344572,
    0.9897893302396132,
    0.9954608693395819,
    0.9708650568301225,
    0.9945059257318244,
    0.9990017620367713,
    0.9993256835414662,
    0.9988137903595806,
    0.9997376201079939,
    0.9991875271636956,
    0.9993181108133978,
    0.999584287504935,
    0.9998536816185439,
    0.9997505197239098,
    0.9991454683321326,
    0.999133923476297,
]
f5 = [
    0.7938522787939981,
    0.7694050486111035,
    0.7480412378457674,
    0.8199626700134939,
    0.8645715944179992,
    0.8485227785645753,
    0.8465648733875053,
    0.8965522747124327,
    0.827742930090148,
    0.9112783881804412,
    0.9139447966113794,
    0.9281816459014978,
    0.9411485779006552,
    0.9404314259628063,
    0.9614250722250383,
    0.9584089439006116,
    0.9634622669864772,
    0.9592553879950669,
    0.9910434844316107,
    0.9841799789592232,
    0.9894733969107363,
    0.9834673225807649,
    0.9890957397071972,
    0.987736442163077,
    0.9743966729226156,
    0.9961978043344126,
    0.9908528542350714,
    0.9952964918337713,
    0.9933659678810496,
    0.9986090768672631,
    0.9937821062565149,
    0.9984309859572951,
    0.9968025081053915,
    0.9978344504380747,
    0.9963342123828373,
    0.9979653064573281,
    0.9981253316975227
]


labels = [2, 3, 4, 5]
d = [range(2, 10), range(3, 15), range(3, 30), range(3, 40)]
f = [f2, f3, f4, f5]
d_up = [4, 11, 26, 57]
colors = ['blue', 'orange', 'green', 'red']
plt.figure(figsize=(5, 2))
for i in range(len(d)):
    # find index of element in f[i] that large than 0.99 first
    idx = next((idx for idx, val in enumerate(f[i]) if val > 0.99), None)
    # plot point with x is d[idx] and y is f[i][idx]
    # marker without color inside
    
    plt.scatter(d[i][idx], f[i][idx], edgecolors=colors[i], facecolors='none', s=20)
    plt.plot(d[i], f[i], color=colors[i], label=labels[i])
# Plot line parallel with y axis
    plt.axvline(x=d_up[i], color=colors[i], linestyle='--', linewidth=0.5)
plt.ylim(0.5, 1.05)
plt.xlabel('$d$')
plt.ylabel('$F_{QC}$')
plt.legend(ncol=2, title='Number of qubits')
plt.savefig('./images/fqc1.svg')
plt.show()
